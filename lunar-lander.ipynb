# %%
# import os

# os.kill(os.getpid(), 9)

# from pyvirtualdisplay import Display

# virtual_display = Display(visible=0, size=(1400, 900))
# virtual_display.start()

# %%
# RL starts here

import gymnasium

from stable_baselines3 import PPO # Proximal Policy Optimization
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create the LunarLander environment
env = gymnasium.make("LunarLander-v3")

# Create the policy model
model = PPO('MlpPolicy', env, verbose=1, device='cpu')


model.learn(total_timesteps=int(2e5))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | -182     |
# | time/              |          |
# |    fps             | 1287     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.9        |
# |    ep_rew_mean          | -209        |
# | time/                   |             |
# |    fps                  | 982         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007260538 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000848    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 630         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | -189        |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011373784 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0326     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 780         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 2.04e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | -172         |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076879086 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0118      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 280          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00907     |
# |    value_loss           | 795          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91           |
# |    ep_rew_mean          | -155         |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0071641724 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0122       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00858     |
# |    value_loss           | 482          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.3         |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0048775836 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00569     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00822     |
# |    value_loss           | 413          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 91.5       |
# |    ep_rew_mean          | -122       |
# | time/                   |            |
# |    fps                  | 842        |
# |    iterations           | 7          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00839724 |
# |    clip_fraction        | 0.0278     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.00144   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 115        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00538   |
# |    value_loss           | 474        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.6         |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0074578705 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00442     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 139          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00551     |
# |    value_loss           | 296          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.9        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009984776 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.0077     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 209         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 334         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009698083 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.193      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 320         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011913236 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0583      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 240         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -98.4       |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 12          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012694279 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 281         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -91.8       |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007393281 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 180         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 389         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | -90.7       |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 14          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007976209 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.0956      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 288         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -82.7       |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 15          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008711975 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 211         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -76.6        |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0076912064 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.3         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | -74.6        |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 17           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0066690487 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0576       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00639     |
# |    value_loss           | 270          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -71.2       |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 18          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010278553 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 283         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | -68.7       |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010025885 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 20          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009534737 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00996    |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | -68         |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 21          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008240476 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | -65.6       |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008330111 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 221         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | -63.5       |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 23          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014061061 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 137         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 281        |
# |    ep_rew_mean          | -61.3      |
# | time/                   |            |
# |    fps                  | 810        |
# |    iterations           | 24         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01144214 |
# |    clip_fraction        | 0.0742     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.646      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30         |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00979   |
# |    value_loss           | 56.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | -61        |
# | time/                   |            |
# |    fps                  | 810        |
# |    iterations           | 25         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00577838 |
# |    clip_fraction        | 0.0366     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.219      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.3       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00466   |
# |    value_loss           | 189        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | -57.6        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 26           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0103361495 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.8         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0082      |
# |    value_loss           | 143          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | -54.2       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 27          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007090775 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 51.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 28          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.021374565 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 88          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 372         |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 29          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006032181 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 145         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 389          |
# |    ep_rew_mean          | -49.6        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 30           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0049488866 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.0767      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 405         |
# |    ep_rew_mean          | -50         |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 31          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011358742 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.31        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 21.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 423        |
# |    ep_rew_mean          | -47.8      |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 32         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00901374 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.4       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00686   |
# |    value_loss           | 74.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 441        |
# |    ep_rew_mean          | -48.7      |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 33         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00783486 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.95       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0075    |
# |    value_loss           | 23         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 458         |
# |    ep_rew_mean          | -46.8       |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 34          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005434552 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.24        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0065     |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | -45.7       |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 35          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011765047 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.12        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -44.5        |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 36           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0057476996 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.4         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 52.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 512          |
# |    ep_rew_mean          | -41.3        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 37           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0062300973 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 69.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 528         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 38          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008544436 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 49.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 545         |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 39          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011216753 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 563         |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 40          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009623377 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.67        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 8.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 41          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010401368 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 42          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005342827 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.69        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 95          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 613         |
# |    ep_rew_mean          | -16         |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 43          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011467245 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | -7.25       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 44          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008514565 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 110         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 632        |
# |    ep_rew_mean          | 0.119      |
# | time/                   |            |
# |    fps                  | 808        |
# |    iterations           | 45         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00394204 |
# |    clip_fraction        | 0.0209     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.894     |
# |    explained_variance   | 0.483      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 53.4       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00227   |
# |    value_loss           | 99.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 637          |
# |    ep_rew_mean          | 6.11         |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 46           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0037618051 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.5         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 47           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0050861323 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.905       |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.5         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 87.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 663          |
# |    ep_rew_mean          | 21.9         |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 48           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0026871236 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.9         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 158          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 679         |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 49          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006425645 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 147         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 689          |
# |    ep_rew_mean          | 35.4         |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 50           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0066404436 |
# |    clip_fraction        | 0.0996       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62           |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 703          |
# |    ep_rew_mean          | 37.5         |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 51           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0073805167 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00587     |
# |    value_loss           | 197          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 713          |
# |    ep_rew_mean          | 42.7         |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 52           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0051328978 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.814       |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.9         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 122          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 53          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008767268 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 132         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 713        |
# |    ep_rew_mean          | 58.4       |
# | time/                   |            |
# |    fps                  | 807        |
# |    iterations           | 54         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.00313944 |
# |    clip_fraction        | 0.0234     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.883     |
# |    explained_variance   | 0.549      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 55.8       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.00166   |
# |    value_loss           | 79.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 702          |
# |    ep_rew_mean          | 70.1         |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 55           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0046575405 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 81          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.004506914 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 197         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 82          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006846876 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 126         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 83           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0076449066 |
# |    clip_fraction        | 0.0836       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0064      |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 84           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0037189494 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.1         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 186          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 85          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.006722318 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 86          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.012710003 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 38.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 87          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006514197 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 295         |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 218         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 413          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 88           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0060334355 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 121          |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 89          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.005624743 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 407          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 90           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0026514898 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.6         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 99.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 91           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0059974417 |
# |    clip_fraction        | 0.069        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 128          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 92          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005900125 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00411    |
# |    value_loss           | 31.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 93           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0032865684 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.753       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.76         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000989    |
# |    value_loss           | 114          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 94           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0040278137 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.8         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 289          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 389        |
# |    ep_rew_mean          | 160        |
# | time/                   |            |
# |    fps                  | 801        |
# |    iterations           | 95         |
# |    time_elapsed         | 242        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.00584264 |
# |    clip_fraction        | 0.0653     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.745     |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.1       |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.000288  |
# |    value_loss           | 57         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 96           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0027150204 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 151          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 388        |
# |    ep_rew_mean          | 152        |
# | time/                   |            |
# |    fps                  | 800        |
# |    iterations           | 97         |
# |    time_elapsed         | 248        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00619587 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.773     |
# |    explained_variance   | 0.458      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.4       |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.00363   |
# |    value_loss           | 257        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 800          |
# |    iterations           | 98           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0038418267 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.4         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 235          |
# ------------------------------------------

# %%
# for i in range(20):
#     action = env.action_space.sample()
#     print("Action Taken:", action)

#     # Take the action and apply it to the environment
#     observation, reward, terminated, truncated, info = env.step(action)

#     print(f"\nStep {i}")
#     print("Obsevation:", observation) 
#     print("Reward:", reward)
#     print("Terminated:", terminated)
#     print("Info:", info)

#     if terminated or truncated:
#         print("Env is reset")
#         observation, info = env.reset()

env.close()
